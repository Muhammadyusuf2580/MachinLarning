# %% [markdown]
# <a href="https://colab.research.google.com/github/pocerface6200/MachinLarning/blob/main/Copy_of_Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
data = pd.read_csv("/content/coffee_shop_revenue.csv")
display(data)
# Out:
#       Number_of_Customers_Per_Day  Average_Order_Value  \
# 0                             152                 6.74
# 1                             485                 4.50
# 2                             398                 9.09
# 3                             320                 8.48
# 4                             156                 7.44
# ...                           ...                  ...
# 1995                          372                 6.41
# 1996                          105                 3.01
# 1997                           89                 5.28
# 1998                          403                 9.41
# 1999                           89                 6.88
#
#       Operating_Hours_Per_Day  Number_of_Employees  Marketing_Spend_Per_Day  \
# 0                          14                    4                   106.62
# 1                          12                    8                    57.83
# ...

# %%
dt = data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Number_of_Customers_Per_Day  2000 non-null   int64
#  1   Average_Order_Value          2000 non-null   float64
#  2   Operating_Hours_Per_Day      2000 non-null   int64
#  3   Number_of_Employees          2000 non-null   int64
#  4   Marketing_Spend_Per_Day      2000 non-null   float64
#  5   Location_Foot_Traffic        2000 non-null   int64
#  6   Daily_Revenue                2000 non-null   float64
# dtypes: float64(3), int64(4)
# memory usage: 109.5 KB

# %%
correlation_matrix = data.corr()

# %%
plt.figure(figsize=(10,6))
sb.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Korrelyatsiya matritsasi")
plt.show()

# %%
data.head()
# Out:
#    Number_of_Customers_Per_Day  Average_Order_Value  Operating_Hours_Per_Day  \
# 0                          152                 6.74                       14
# 1                          485                 4.50                       12
# 2                          398                 9.09                        6
# 3                          320                 8.48                       17
# 4                          156                 7.44                       17
#
#    Number_of_Employees  Marketing_Spend_Per_Day  Location_Foot_Traffic  \
# 0                    4                   106.62                     97
# 1                    8                    57.83                    744
# 2                    6                    91.76                    636
# 3                    4                   462.63                    770
# 4                    2                   412.52                    232
#
#    Daily_Revenue
# 0        1547.81
# 1        2084.68
# 2        3118.39
# ...

# %%
data.columns
# Out:
# Index(['Number_of_Customers_Per_Day', 'Average_Order_Value',
#        'Operating_Hours_Per_Day', 'Number_of_Employees',
#        'Marketing_Spend_Per_Day', 'Location_Foot_Traffic', 'Daily_Revenue'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Number_of_Customers_Per_Day    0
# Average_Order_Value            0
# Operating_Hours_Per_Day        0
# Number_of_Employees            0
# Marketing_Spend_Per_Day        0
# Location_Foot_Traffic          0
# Daily_Revenue                  0
# dtype: int64

# %%
data.describe()
# Out:
#        Number_of_Customers_Per_Day  Average_Order_Value  \
# count                  2000.000000          2000.000000
# mean                    274.296000             6.261215
# std                     129.441933             2.175832
# min                      50.000000             2.500000
# 25%                     164.000000             4.410000
# 50%                     275.000000             6.300000
# 75%                     386.000000             8.120000
# max                     499.000000            10.000000
#
#        Operating_Hours_Per_Day  Number_of_Employees  Marketing_Spend_Per_Day  \
# count              2000.000000          2000.000000              2000.000000
# mean                 11.667000             7.947000               252.614160
# std                   3.438608             3.742218               141.136004
# min                   6.000000             2.000000                10.120000
# ...

# %%
data.hist(figsize=(10,8), bins=20)
plt.show()

# %%
sb.displot(data["Average_Order_Value"], kde=True, bins=20)
plt.title("Buyurtma qiymatining taqsimoti")
plt.show()

# %%
sb.countplot(x=data["Number_of_Employees"])
plt.title("Xodimlar soni bo‘yicha taqsimot")
plt.show()

# %%
sb.scatterplot(x="Marketing_Spend_Per_Day", y="Number_of_Customers_Per_Day", data=data)
plt.title("Reklama harajati va mijozlar soni bog‘liqligi")
plt.show()

# %%
sb.pairplot(data)
plt.show()

# %%
sb.regplot(x="Marketing_Spend_Per_Day", y="Number_of_Customers_Per_Day", data=data)
plt.title("Reklama harajati va mijozlar soni regression analizi")
plt.show()

# %%
plt.figure(figsize=(8, 6))  # Set the figure size for better readability
plot_tree(dt_regressor, feature_names=df.columns, filled=True, rounded=True)
plt.title("Decision Tree for Coffe Shop Revenus Prediction")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-d94555f606f2> in <cell line: 0>()
#       1 plt.figure(figsize=(8, 6))  # Set the figure size for better readability
# ----> 2 plot_tree(dt_regressor, feature_names=df.columns, filled=True, rounded=True)
#       3 plt.title("Decision Tree for Coffe Shop Revenus Prediction")
#       4 plt.show()
#
# NameError: name 'plot_tree' is not defined
